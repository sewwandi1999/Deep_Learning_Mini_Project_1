# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2
import os


from google.colab import drive
drive.mount('/content/drive')



os.chdir("/content/drive/My Drive/PS-2019-175/")
os.getcwd()



img = image.load_img("Training/da/da.1.jpeg")


plt.imshow(img)



cv2.imread("Training/da/da.1.jpeg").shape


train = ImageDataGenerator(rescale = 1/255)


validation = ImageDataGenerator(rescale = 1/255)


train_dataset = train.flow_from_directory('Training/',
                                          target_size = (200,200),
                                          batch_size = 3,
                                          class_mode = 'binary')


validation_dataset = validation.flow_from_directory('Validation/',
                                                   target_size = (200,200),
                                                   batch_size = 3,
                                                   class_mode = 'binary')


train_dataset.class_indices


train_dataset.classes


model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,(3,3),activation = 'relu',input_shape = (200,200,3)),
                                   # MaxPooling layer with pool size (2, 2)
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Convolutional layer with 32 filters, each of size (3, 3), and ReLU activation
                                    tf.keras.layers.Conv2D(32,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Convolutional layer with 64 filters, each of size (3, 3), and ReLU activation
                                    tf.keras.layers.Conv2D(64,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Flatten layer to convert 3D feature maps to 1D feature vectors
                                    tf.keras.layers.Flatten(),
                                   # Dense (fully connected) layer with 512 units and ReLU activation
                                    tf.keras.layers.Dense(512,activation = 'relu'),
                                   # Output layer with 1 unit and sigmoid activation for binary classification
                                    tf.keras.layers.Dense(1,activation = 'sigmoid')
                                    ])


model.compile(loss = 'binary_crossentropy',
              optimizer = RMSprop(lr=0.001),
              metrics = ['accuracy'])






model_fit = model.fit(train_dataset,
                      steps_per_epoch = 5,
                      epochs = 30,
                      validation_data = validation_dataset)




validation_dataset.class_indices


dir_path = 'Testing/'


for i in os.listdir(dir_path):
    # Load the image and resize it to the target size
  img = image.load_img(dir_path+ i,target_size=(200,200))
  # Display the image using matplotlib
  plt.imshow(img)
  plt.show()


  # Convert the image to a NumPy array and add an extra dimension
  X = image.img_to_array(img)
  X = np.expand_dims(X,axis = 0)
# Stack the array vertically to create a batch of images
  images = np.vstack([X])
# Make a prediction using the trained model
  val = model.predict(images)
# Check the predicted value and print the corresponding class label
  if val == 0:
    print("This is Letter 'da' in Sinhala")
  else:
    print("This is Letter 'ma' in Sinhala")
# Out:
# Mounted at /content/drive
# Found 100 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 5/5 [==============================] - 28s 7s/step - loss: 4.8259 - accuracy: 0.5333 - val_loss: 0.7658 - val_accuracy: 0.5000
# Epoch 2/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.8452 - accuracy: 0.6000 - val_loss: 0.7007 - val_accuracy: 0.5000
# Epoch 3/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.8053 - accuracy: 0.6000 - val_loss: 0.6849 - val_accuracy: 0.5000
# Epoch 4/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.7142 - accuracy: 0.3333 - val_loss: 0.6676 - val_accuracy: 0.5200
# Epoch 5/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.7576 - accuracy: 0.4615 - val_loss: 0.6654 - val_accuracy: 0.5000
# Epoch 6/30
# 5/5 [==============================] - 9s 2s/step - loss: 0.6961 - accuracy: 0.4667 - val_loss: 0.6329 - val_accuracy: 0.8000
# Epoch 7/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.6821 - accuracy: 0.6000 - val_loss: 0.5867 - val_accuracy: 0.7100
# Epoch 8/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.6342 - accuracy: 0.7333 - val_loss: 0.5689 - val_accuracy: 0.8200
# Epoch 9/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.6571 - accuracy: 0.6667 - val_loss: 0.6228 - val_accuracy: 0.5400
# Epoch 10/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.5340 - accuracy: 0.7333 - val_loss: 0.3685 - val_accuracy: 0.8700
# Epoch 11/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.2134 - accuracy: 0.9333 - val_loss: 0.1894 - val_accuracy: 0.9200
# Epoch 12/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.3586 - accuracy: 0.8667 - val_loss: 0.3040 - val_accuracy: 0.8700
# Epoch 13/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.1603 - accuracy: 0.8667 - val_loss: 0.1209 - val_accuracy: 0.9300
# Epoch 14/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.0891 - accuracy: 1.0000 - val_loss: 0.1081 - val_accuracy: 0.9600
# Epoch 15/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.0664 - accuracy: 1.0000 - val_loss: 0.1616 - val_accuracy: 0.9200
# Epoch 16/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1198 - accuracy: 0.9333 - val_loss: 0.0650 - val_accuracy: 0.9900
# Epoch 17/30
# 5/5 [==============================] - 4s 959ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9800
# Epoch 18/30
# 5/5 [==============================] - 7s 2s/step - loss: 0.1014 - accuracy: 0.9231 - val_loss: 0.0730 - val_accuracy: 0.9700
# Epoch 19/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.2251 - accuracy: 0.9333 - val_loss: 0.3255 - val_accuracy: 0.8600
# Epoch 20/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1467 - accuracy: 0.9231 - val_loss: 0.1443 - val_accuracy: 0.9300
# Epoch 21/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.2274 - accuracy: 0.9333 - val_loss: 0.1167 - val_accuracy: 0.9300
# Epoch 22/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2727 - accuracy: 0.8462 - val_loss: 0.0238 - val_accuracy: 1.0000
# Epoch 23/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.1082 - accuracy: 0.9333 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 24/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.0411 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 25/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 26/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 27/30
# 5/5 [==============================] - 5s 999ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 28/30
# 5/5 [==============================] - 8s 2s/step - loss: 5.5554e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 29/30
# 5/5 [==============================] - 4s 990ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 30/30
# 5/5 [==============================] - 9s 2s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 127ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 61ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 57ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 54ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 66ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 40ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 41ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 44ms/step
# This is Letter 'ma' in Sinhala
# 1/1 [==============================] - 0s 53ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 51ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 50ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 53ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 53ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'da' in Sinhala
# 1/1 [==============================] - 0s 40ms/step
# This is Letter 'da' in Sinhala
